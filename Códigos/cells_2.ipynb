# %% [markdown]
# ### Arquitectura UNet para la estimación de mapas de radio y clasificación de celdas, para escenarios de interiores

# %% [markdown]
# #### Cargue de librerías

# %%
import tensorflow as tf 
from tensorflow.keras import optimizers
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Activation, ReLU
from tensorflow.keras.layers import BatchNormalization, Conv2DTranspose, Concatenate, Dropout
from tensorflow.keras.models import Model, Sequential
import numpy as np
import os
from skimage import io
import matplotlib.pyplot as plt
from tqdm import tqdm 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import time
import random

# %% [markdown]
# ### Inicialización de algunos parámetros principales

# %%
n_classes = 2 # Cuando n_classes es igual a 1 no se puede especificar simulation = cells, ya que el sistema no realiza esta práctica, al asumirse que con
# 1 celda se cubre toda el área de funcionamiento.
simulation = 'cells'
porc_val = 0.2
epochs = 50
batch_size = 16
learning_rate = 1e-3
higth_img = 256 
width_img = 256
scenarios = 10
positions = 1000 # Se elige cuántas simulaciones se desean cargan de 1000 totales por escenario

# Algunas configuraciones para el optimizador
"""lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate = 1e-2,
    decay_steps = 5000,
    decay_rate = 0.9)"""

dir_dataset_esc = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/Escenarios'
if n_classes == 3:
    dir_dataset_pos = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/3AP/Transmisores'
    dir_masks = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/3AP/Celdas'
    dir_maps = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/3AP/Mapas'
if n_classes == 2:
    dir_dataset_pos = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/2AP/Transmisores'
    dir_masks = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/2AP/Celdas'
    dir_maps = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/2AP/Mapas'
if n_classes == 1:
    dir_dataset_pos = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/1AP/Transmisores'
    dir_maps = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/1AP/Mapas'

# %% [markdown]
# #### Funciones para definir la arquitectura UNet

# %%
################################################################
def block_1convolution(input_b1 = None, filters = None, kernel = None, train = True):
    conv1 = Conv2D(filters, kernel, padding = 'same', kernel_initializer='he_normal', trainable = train)(input_b1)
    batch_norm1 = BatchNormalization(trainable = train)(conv1)
    act1 = ReLU(trainable = train)(batch_norm1)
    
    return act1
################################################################
def block_2convolution(input_b2 = None, filters = None, kernel = None, train = True):
    conv1 = Conv2D(filters//2, kernel, padding = 'same', kernel_initializer='he_normal', trainable = train)(input_b2)
    batch_norm1 = BatchNormalization(trainable = train)(conv1)
    act1 = ReLU(trainable = train)(batch_norm1)
    
    conv2 = Conv2D(filters, kernel, padding = 'same', kernel_initializer='he_normal', trainable = train)(act1)
    batch_norm2 = BatchNormalization(trainable = train)(conv2)
    act2 = ReLU(trainable = train)(batch_norm2)
    
    return act2
###############################################################
def encoder(input_enc = None, filters = None, kernel = None, train = True):
    enc1 = block_2convolution(input_enc, filters, kernel, train = train)
    MaxPool1 = MaxPooling2D(strides = (2,2), trainable = train)(enc1)
    return enc1, MaxPool1
###############################################################
def decoder(input_dec = None, skip = None, filters = None, kernel = None, train = True):
    Upsample = Conv2DTranspose(filters, (2, 2), strides=2, padding = 'same', trainable = train)(input_dec)
    Connect_Skip = Concatenate(trainable = train)([Upsample, skip])
    out = block_2convolution(Connect_Skip, filters, kernel, train = train)
    return out
###############################################################
def U_Net(n_classes = None, higth_img = None, width_img = None, channels_img = None, 
          simulation = ''):

    # Entrada
    input1 = Input((higth_img, width_img, channels_img))
    
    #256,256,profundidad
    skip1_1, encoder_1_1 = encoder(input1, filters = 6, kernel = 3) #128,128,profundidad
    skip2_1, encoder_2_1 = encoder(encoder_1_1, filters = 40, kernel = 3) #64,64,profundidad
    skip3_1, encoder_3_1 = encoder(encoder_2_1, filters = 50, kernel = 3) #32,32,profundidad
    skip4_1, encoder_4_1 = encoder(encoder_3_1, filters = 60, kernel = 3) #16,16,profundidad
    skip5_1, encoder_5_1 = encoder(encoder_4_1, filters = 100, kernel = 3) #8,8,profundidad
    skip6_1, encoder_6_1 = encoder(encoder_5_1, filters = 200, kernel = 3) #4,4,profundidad
    skip7_1, encoder_7_1 = encoder(encoder_6_1, filters = 300, kernel = 3) #2,2,profundidad
    skip8_1, encoder_8_1 = encoder(encoder_7_1, filters = 400, kernel = 3) #1,1,profundidad
    
    conv_block_1 = block_2convolution(encoder_8_1, filters = 600, kernel = 3) #1,1,profundidad
    
    decoder_1_1 = decoder(conv_block_1, skip8_1, filters = 400, kernel = 3) #2,2,profundidad
    decoder_2_1 = decoder(decoder_1_1, skip7_1, filters = 300, kernel = 3) #4,4,profundidad
    decoder_3_1 = decoder(decoder_2_1, skip6_1, filters = 200, kernel = 3) #8,8,profundidad
    decoder_4_1 = decoder(decoder_3_1, skip5_1, filters = 100, kernel = 3) #16,16,profundidad
    decoder_5_1 = decoder(decoder_4_1, skip4_1, filters = 60, kernel = 3) #32,32,profundidad
    decoder_6_1 = decoder(decoder_5_1, skip3_1, filters = 50, kernel = 3) #64,64,profundidad
    decoder_7_1 = decoder(decoder_6_1, skip2_1, filters = 40, kernel = 3) #128,128,profundidad       
    decoder_8_1 = decoder(decoder_7_1, skip1_1, filters = 20, kernel = 3) #256,256,profundidad
    
    conc1_1 = Concatenate()([decoder_8_1, input1])
    
    aditional_ = block_1convolution(conc1_1, filters = 20, kernel = 3) #256,256,profundidad
  
    conc2_1 = Concatenate()([aditional_, input1])
    
    if simulation == 'maps':
        out_1 = Conv2D(1, 1, padding = 'same', activation = 'relu', kernel_initializer='he_normal')(conc2_1)
    if simulation == 'cells':
        out_1 = Conv2D(n_classes, 1, padding = 'same', activation = 'softmax', kernel_initializer='he_normal')(conc2_1)
    
    model = Model(input1, out_1)
    
    return model
###############################################################

# %% [markdown]
# #### Visualización de la Arquitectura

# %%
if simulation == 'cells':
    channels_img = n_classes + 2
if simulation == 'maps':
    channels_img = n_classes + 1

model = U_Net(n_classes = n_classes, channels_img = channels_img, simulation = simulation)

model.summary()

for l in model.layers:
    print(l.name, l.trainable)

tf.keras.utils.plot_model(model, 'C:/Users/GIIEE/Documents/johan/proyecto/modelos/model.png', 
                          show_shapes=False, show_layer_names=True, 
                          rankdir='TB', expand_nested=False, dpi=110)
# Out:
# WARNING:tensorflow:From c:\Users\GIIEE\Documents\johan\conda\envs\tensor\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 3 111         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, None, None, 3 12          conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, None, None, 3 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 6 168         re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 6 24          conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, None, None, 6 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 6 0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 2 1100        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 2 80          conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, None, None, 2 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 4 7240        re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 4 160         conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, None, None, 4 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 4 0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 2 9025        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 2 100         conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, None, None, 2 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 5 11300       re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 5 200         conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, None, None, 5 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 5 0           re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 3 13530       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 3 120         conv2d_6[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, None, None, 3 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 6 16260       re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 6 240         conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, None, None, 6 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 6 0           re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 5 27050       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 5 200         conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, None, None, 5 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 45100       re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 1 400         conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, None, None, 1 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, None, None, 1 0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 1 90100       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 1 400         conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, None, None, 1 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 2 180200      re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 2 800         conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, None, None, 2 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, None, None, 2 0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 1 270150      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 1 600         conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, None, None, 1 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 3 405300      re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 3 1200        conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, None, None, 3 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, None, None, 3 0           re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 540200      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 2 800         conv2d_14[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, None, None, 2 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 4 720400      re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 4 1600        conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, None, None, 4 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, None, None, 4 0           re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 3 1080300     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 3 1200        conv2d_16[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, None, None, 3 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 6 1620600     re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 6 2400        conv2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, None, None, 6 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, None, None, 4 960400      re_lu_17[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, None, None, 8 0           conv2d_transpose[0][0]
#                                                                  re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 1440200     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 2 800         conv2d_18[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, None, None, 2 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 4 720400      re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 4 1600        conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, None, None, 4 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, None, None, 3 480300      re_lu_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 6 0           conv2d_transpose_1[0][0]
#                                                                  re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 1 810150      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 1 600         conv2d_20[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, None, None, 1 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 3 405300      re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 3 1200        conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, None, None, 3 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, None, None, 2 240200      re_lu_21[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 4 0           conv2d_transpose_2[0][0]
#                                                                  re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 1 360100      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 1 400         conv2d_22[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, None, None, 1 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 2 180200      re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 2 800         conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, None, None, 2 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, None, None, 1 80100       re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 2 0           conv2d_transpose_3[0][0]
#                                                                  re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 5 90050       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 5 200         conv2d_24[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, None, None, 5 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 1 45100       re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 1 400         conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, None, None, 1 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, None, None, 6 24060       re_lu_25[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, None, None, 1 0           conv2d_transpose_4[0][0]
#                                                                  re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 3 32430       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 3 120         conv2d_26[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, None, None, 3 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 6 16260       re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 6 240         conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, None, None, 6 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, None, None, 5 12050       re_lu_27[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, None, None, 1 0           conv2d_transpose_5[0][0]
#                                                                  re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 2 22525       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 2 100         conv2d_28[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, None, None, 2 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 5 11300       re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 5 200         conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, None, None, 5 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, None, None, 4 8040        re_lu_29[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, None, None, 8 0           conv2d_transpose_6[0][0]
#                                                                  re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 2 14420       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 2 80          conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, None, None, 2 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 4 7240        re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 4 160         conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, None, None, 4 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, None, None, 2 3220        re_lu_31[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, None, None, 2 0           conv2d_transpose_7[0][0]
#                                                                  re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 1 2350        concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 1 40          conv2d_32[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, None, None, 1 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 2 1820        re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 2 80          conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, None, None, 2 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, None, None, 2 0           re_lu_33[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 2 4340        concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 2 80          conv2d_34[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, None, None, 2 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, None, None, 2 0           re_lu_34[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 2 50          concatenate_9[0][0]
# ==================================================================================================
# Total params: 11,028,375
# Trainable params: 11,019,557
# Non-trainable params: 8,818
# __________________________________________________________________________________________________
# input_1 True
# conv2d True
# batch_normalization True
# re_lu True
# conv2d_1 True
# batch_normalization_1 True
# re_lu_1 True
# max_pooling2d True
# conv2d_2 True
# batch_normalization_2 True
# re_lu_2 True
# conv2d_3 True
# batch_normalization_3 True
# re_lu_3 True
# max_pooling2d_1 True
# conv2d_4 True
# batch_normalization_4 True
# re_lu_4 True
# conv2d_5 True
# batch_normalization_5 True
# re_lu_5 True
# max_pooling2d_2 True
# conv2d_6 True
# batch_normalization_6 True
# re_lu_6 True
# conv2d_7 True
# batch_normalization_7 True
# re_lu_7 True
# max_pooling2d_3 True
# conv2d_8 True
# batch_normalization_8 True
# re_lu_8 True
# conv2d_9 True
# batch_normalization_9 True
# re_lu_9 True
# max_pooling2d_4 True
# conv2d_10 True
# batch_normalization_10 True
# re_lu_10 True
# conv2d_11 True
# batch_normalization_11 True
# re_lu_11 True
# max_pooling2d_5 True
# conv2d_12 True
# batch_normalization_12 True
# re_lu_12 True
# conv2d_13 True
# batch_normalization_13 True
# re_lu_13 True
# max_pooling2d_6 True
# conv2d_14 True
# batch_normalization_14 True
# re_lu_14 True
# conv2d_15 True
# batch_normalization_15 True
# re_lu_15 True
# max_pooling2d_7 True
# conv2d_16 True
# batch_normalization_16 True
# re_lu_16 True
# conv2d_17 True
# batch_normalization_17 True
# re_lu_17 True
# conv2d_transpose True
# concatenate True
# conv2d_18 True
# batch_normalization_18 True
# re_lu_18 True
# conv2d_19 True
# batch_normalization_19 True
# re_lu_19 True
# conv2d_transpose_1 True
# concatenate_1 True
# conv2d_20 True
# batch_normalization_20 True
# re_lu_20 True
# conv2d_21 True
# batch_normalization_21 True
# re_lu_21 True
# conv2d_transpose_2 True
# concatenate_2 True
# conv2d_22 True
# batch_normalization_22 True
# re_lu_22 True
# conv2d_23 True
# batch_normalization_23 True
# re_lu_23 True
# conv2d_transpose_3 True
# concatenate_3 True
# conv2d_24 True
# batch_normalization_24 True
# re_lu_24 True
# conv2d_25 True
# batch_normalization_25 True
# re_lu_25 True
# conv2d_transpose_4 True
# concatenate_4 True
# conv2d_26 True
# batch_normalization_26 True
# re_lu_26 True
# conv2d_27 True
# batch_normalization_27 True
# re_lu_27 True
# conv2d_transpose_5 True
# concatenate_5 True
# conv2d_28 True
# batch_normalization_28 True
# re_lu_28 True
# conv2d_29 True
# batch_normalization_29 True
# re_lu_29 True
# conv2d_transpose_6 True
# concatenate_6 True
# conv2d_30 True
# batch_normalization_30 True
# re_lu_30 True
# conv2d_31 True
# batch_normalization_31 True
# re_lu_31 True
# conv2d_transpose_7 True
# concatenate_7 True
# conv2d_32 True
# batch_normalization_32 True
# re_lu_32 True
# conv2d_33 True
# batch_normalization_33 True
# re_lu_33 True
# concatenate_8 True
# conv2d_34 True
# batch_normalization_34 True
# re_lu_34 True
# concatenate_9 True
# conv2d_35 True
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %% [markdown]
# #### Cargue de los datos

# %%
def data(simulation = '', n_classes = None, dir_dataset_pos = '', dir_masks = '', dir_maps = '',
        dir_dataset_esc = '', scenarios = None, positions = None):

    maps_inds = np.arange(1, (scenarios * positions) + 1, 1, dtype = np.int16) 
    np.random.seed(42) # Semilla para tener siempre los numeros aleatorios
    np.random.shuffle(maps_inds)

    train_images = []

    train_masks = [] 

    for idx in tqdm(maps_inds):
        idxr = np.floor((idx - 1)/positions).astype(int)
        idxc = idx - (idxr * positions)
        dataset_map_ind = idxr + 1

        name1 = str(dataset_map_ind) + ".png"
        name0 = str(dataset_map_ind) + "_" + str(idxc) + ".png"
        name2 = str(dataset_map_ind) + "_" + str(idxc) + ".png"
        
        if n_classes > 1:
            name2 = str(dataset_map_ind) + "_" + str(idxc) + "_" + '1' + ".png"
            name3 = str(dataset_map_ind) + "_" + str(idxc) + "_" + '2' + ".png"
            
        if n_classes > 2:
            name4 = str(dataset_map_ind) + "_" + str(idxc) + "_" + '3' + ".png"

        img_name_buildings = os.path.join(dir_dataset_esc, name1)
        image_buildings = np.asarray(io.imread(img_name_buildings))/255

        img_name_Tx1 = os.path.join(dir_dataset_pos, name2)
        image_Tx1 = np.asarray(io.imread(img_name_Tx1))/255

        if n_classes > 1:
            img_name_Tx2 = os.path.join(dir_dataset_pos, name3)
            image_Tx2 = np.asarray(io.imread(img_name_Tx2))/255

        if n_classes > 2:
            img_name_Tx3 = os.path.join(dir_dataset_pos, name4)
            image_Tx3 = np.asarray(io.imread(img_name_Tx3))/255

        if n_classes == 1:
            img = np.stack([image_buildings, image_Tx1], axis = 2)  
            train_images.append(img)    
            
        if n_classes == 2 and simulation == 'maps':
            img = np.stack([image_buildings, image_Tx1, image_Tx2], axis = 2)  
            train_images.append(img)
            
        if n_classes == 2 and simulation == 'cells':
            maps1 = os.path.join(dir_maps, name0)
            maps1 = np.asarray(io.imread(maps1))/255
            img = np.stack([image_buildings, image_Tx1, image_Tx2, maps1], axis = 2)  
            train_images.append(img)
            
        if n_classes == 3 and simulation == 'maps':
            img = np.stack([image_buildings, image_Tx1, image_Tx2, image_Tx3], axis = 2)  
            train_images.append(img) 
            
        if n_classes == 3 and simulation == 'cells':
            maps1 = os.path.join(dir_maps, name0)
            maps1 = np.asarray(io.imread(maps1))/255
            img = np.stack([image_buildings, image_Tx1, image_Tx2, image_Tx3, maps1], axis = 2)  
            train_images.append(img)

        if simulation == 'maps':    
            img_name_out = os.path.join(dir_maps, name0)  
            image_out = np.asarray(io.imread(img_name_out))/255
            train_masks.append(image_out)
        
        if simulation == 'cells' and n_classes != 1:    
            img_name_out = os.path.join(dir_masks, name0)  
            image_out = np.asarray(io.imread(img_name_out))
            train_masks.append(image_out)

    train_images = np.array(train_images)
    train_masks = np.array(train_masks)

    if simulation == 'maps': 
        train_masks_input = np.expand_dims(train_masks, axis=3)
        
    if simulation == 'cells': 
        labelencoder = LabelEncoder()
        n, h, w = train_masks.shape
        train_masks_reshaped = train_masks.reshape(-1,1)
        train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
        train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)
        train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)
    
    return train_images, train_masks_input
    
if n_classes == 1:   
    train_images, train_masks_input = data(simulation = simulation, n_classes = n_classes, 
                                        dir_dataset_pos = dir_dataset_pos, 
                                        dir_maps = dir_maps, dir_dataset_esc = dir_dataset_esc, 
                                        scenarios = scenarios, positions = positions)
else:
    train_images, train_masks_input = data(simulation = simulation, n_classes = n_classes, 
                                       dir_dataset_pos = dir_dataset_pos, dir_masks = dir_masks, 
                                       dir_maps = dir_maps, dir_dataset_esc = dir_dataset_esc, 
                                       scenarios = scenarios, positions = positions)
# Out:
# 100%|██████████| 10000/10000 [00:36<00:00, 270.36it/s]
# c:\Users\GIIEE\Documents\johan\conda\envs\tensor\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
print(train_images.shape)
print(train_masks_input.shape)
# Out:
# (10000, 256, 256, 4)
# (10000, 256, 256, 1)

# %% [markdown]
# #### Separación de los datos en entrenamiento y validación

# %%
X_train, X_val, y_train, y_val = train_test_split(train_images, train_masks_input, 
                                                  test_size = porc_val, random_state = 0)

# %% [markdown]
# #### Visualización de algunos datos

# %%
grapics = 20
imgs = X_train[:grapics,...]
masks = y_train[:grapics,...]
def plot_data(imgs, masks):
    plt.figure(figsize=(20,10))
    for i in range(grapics):
        plt.subplot(4, 5, i+1)
        img=imgs[i,...]
        mask = masks[i, ...]
        plt.imshow(img[:,:,0])
        plt.imshow(mask[:,:,0], alpha=0.5)
        #print(np.unique(mask[:,:,0]))
        
        plt.axis('Off')
    plt.tight_layout()
    plt.show()

plot_data(imgs, masks)

# %% [markdown]
# #### Adecuación de la salida de las celdas en one-hot (si se requiere) y entrenamiento del modelo

# %%
optimizer = optimizers.Adam(learning_rate = learning_rate)

if simulation == 'cells':
    model.compile(optimizer = optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
if simulation == 'maps':
    model.compile(optimizer = optimizer, loss='mean_squared_error')

def training(model, simulation = '', n_classes = None, y_train = [], y_val = [], 
             epochs = None, batch_size = None):
    
    if simulation == 'cells':
        print('Valores únicos de clases: ', np.unique(y_train)) 
        
        y_train_cat = to_categorical(y_train, num_classes = n_classes)

        y_val_cat = to_categorical(y_val, num_classes = n_classes)
        
        callbacks = [keras.callbacks.ModelCheckpoint('C:/Users/GIIEE/Documents/johan/proyecto/modelos/indoor_' + 
                                                     simulation + '_' + str(n_classes) + '.h5', 
                                                     save_best_only = True)]

        history = model.fit(X_train, y_train_cat, 
                            batch_size = batch_size, 
                            verbose = 1, 
                            epochs = epochs, 
                            validation_data = (X_val, y_val_cat), 
                            callbacks = callbacks,
                            shuffle = False)
        
    if simulation == 'maps':
        callbacks = [keras.callbacks.ModelCheckpoint('C:/Users/GIIEE/Documents/johan/proyecto/modelos/indoor_' + 
                                                     simulation + '_' + str(n_classes) + '.h5', 
                                                     save_best_only = True)]

        history = model.fit(X_train, y_train, 
                            batch_size = batch_size, 
                            verbose = 1, 
                            epochs = epochs, 
                            validation_data = (X_val, y_val), 
                            callbacks = callbacks,
                            shuffle = False)
    
    return history
        
    ###############################################################################    
    
# Cambiar de acuerdo al problema *******************************************************
history = training(model = model, simulation = simulation, n_classes = n_classes, 
                   y_train = y_train, y_val = y_val, epochs = epochs, batch_size = batch_size
                   )
# Out:
# Valores únicos de clases:  [0 1]
# WARNING:tensorflow:From c:\Users\GIIEE\Documents\johan\conda\envs\tensor\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 131s 16ms/sample - loss: 0.6949 - acc: 0.5001 - val_loss: 0.6933 - val_acc: 0.5019
# Epoch 2/50
# 8000/8000 [==============================] - 98s 12ms/sample - loss: 0.6525 - acc: 0.5609 - val_loss: 4.8144 - val_acc: 0.5097
# Epoch 3/50
# 8000/8000 [==============================] - 97s 12ms/sample - loss: 0.3664 - acc: 0.8401 - val_loss: 0.3260 - val_acc: 0.8622
# Epoch 4/50
# 8000/8000 [==============================] - 106s 13ms/sample - loss: 0.2727 - acc: 0.8842 - val_loss: 0.2531 - val_acc: 0.8908
# Epoch 5/50
# 8000/8000 [==============================] - 111s 14ms/sample - loss: 0.2186 - acc: 0.9075 - val_loss: 0.2288 - val_acc: 0.9009
# Epoch 6/50
# 8000/8000 [==============================] - 101s 13ms/sample - loss: 0.1763 - acc: 0.9264 - val_loss: 0.2240 - val_acc: 0.9080
# Epoch 7/50
# 8000/8000 [==============================] - 105s 13ms/sample - loss: 0.1389 - acc: 0.9428 - val_loss: 0.2485 - val_acc: 0.8984
# Epoch 8/50
# 8000/8000 [==============================] - 96s 12ms/sample - loss: 0.1090 - acc: 0.9552 - val_loss: 0.5327 - val_acc: 0.7326
# Epoch 9/50
# 8000/8000 [==============================] - 96s 12ms/sample - loss: 0.0879 - acc: 0.9642 - val_loss: 0.6130 - val_acc: 0.7241
# Epoch 10/50
# 8000/8000 [==============================] - 97s 12ms/sample - loss: 0.0732 - acc: 0.9707 - val_loss: 0.1111 - val_acc: 0.9540
# Epoch 11/50
# 8000/8000 [==============================] - 96s 12ms/sample - loss: 0.0637 - acc: 0.9748 - val_loss: 0.1354 - val_acc: 0.9476
# Epoch 12/50
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0561 - acc: 0.9780 - val_loss: 0.0830 - val_acc: 0.9699
# Epoch 13/50
# 8000/8000 [==============================] - 98s 12ms/sample - loss: 0.0517 - acc: 0.9799 - val_loss: 0.0605 - val_acc: 0.9770
# Epoch 14/50
# 8000/8000 [==============================] - 95s 12ms/sample - loss: 0.0511 - acc: 0.9803 - val_loss: 0.5568 - val_acc: 0.7197
# Epoch 15/50
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0461 - acc: 0.9823 - val_loss: 0.0979 - val_acc: 0.9615
# Epoch 16/50
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0396 - acc: 0.9848 - val_loss: 0.0793 - val_acc: 0.9700
# Epoch 17/50
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0369 - acc: 0.9859 - val_loss: 0.0729 - val_acc: 0.9722
# Epoch 18/50
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0339 - acc: 0.9870 - val_loss: 0.0683 - val_acc: 0.9739
# Epoch 19/50
# 8000/8000 [==============================] - 98s 12ms/sample - loss: 0.0329 - acc: 0.9874 - val_loss: 0.0642 - val_acc: 0.9760
# Epoch 20/50
# 8000/8000 [==============================] - 99s 12ms/sample - loss: 0.0298 - acc: 0.9886 - val_loss: 0.0387 - val_acc: 0.9860
# Epoch 21/50
# 8000/8000 [==============================] - 96s 12ms/sample - loss: 0.0307 - acc: 0.9883 - val_loss: 1.0799 - val_acc: 0.7144
# Epoch 22/50
# 8000/8000 [==============================] - 96s 12ms/sample - loss: 0.0306 - acc: 0.9884 - val_loss: 0.0761 - val_acc: 0.9712
# Epoch 23/50
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0253 - acc: 0.9904 - val_loss: 0.9956 - val_acc: 0.6793
# Epoch 24/50
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0254 - acc: 0.9904 - val_loss: 0.1611 - val_acc: 0.9367
# Epoch 25/50
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0247 - acc: 0.9906 - val_loss: 1.2457 - val_acc: 0.7026
# Epoch 26/50
# 8000/8000 [==============================] - 95s 12ms/sample - loss: 0.0260 - acc: 0.9903 - val_loss: 0.0646 - val_acc: 0.9768
# Epoch 27/50
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0211 - acc: 0.9920 - val_loss: 1.3303 - val_acc: 0.6731
# Epoch 28/50
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0204 - acc: 0.9922 - val_loss: 1.3688 - val_acc: 0.6274
# Epoch 29/50
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0294 - acc: 0.9893 - val_loss: 1.0167 - val_acc: 0.6858
# Epoch 30/50
# 8000/8000 [==============================] - 99s 12ms/sample - loss: 0.0235 - acc: 0.9912 - val_loss: 0.8924 - val_acc: 0.7491
# Epoch 31/50
# 8000/8000 [==============================] - 102s 13ms/sample - loss: 0.0223 - acc: 0.9916 - val_loss: 1.0281 - val_acc: 0.7352
# Epoch 32/50
# 8000/8000 [==============================] - 103s 13ms/sample - loss: 0.0200 - acc: 0.9925 - val_loss: 0.8701 - val_acc: 0.7691
# Epoch 33/50
# 8000/8000 [==============================] - 95s 12ms/sample - loss: 0.0231 - acc: 0.9915 - val_loss: 1.1400 - val_acc: 0.7180
# Epoch 34/50
# 8000/8000 [==============================] - 95s 12ms/sample - loss: 0.0199 - acc: 0.9925 - val_loss: 0.2774 - val_acc: 0.8985
# Epoch 35/50
# 8000/8000 [==============================] - 102s 13ms/sample - loss: 0.0151 - acc: 0.9942 - val_loss: 0.0290 - val_acc: 0.9912
# Epoch 36/50
# 8000/8000 [==============================] - 112s 14ms/sample - loss: 0.0160 - acc: 0.9939 - val_loss: 0.4427 - val_acc: 0.8546
# Epoch 37/50
# 8000/8000 [==============================] - 98s 12ms/sample - loss: 0.0164 - acc: 0.9938 - val_loss: 0.4886 - val_acc: 0.8586
# Epoch 38/50
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0176 - acc: 0.9934 - val_loss: 1.0850 - val_acc: 0.7477
# Epoch 39/50
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0320 - acc: 0.9886 - val_loss: 0.1193 - val_acc: 0.9544
# Epoch 40/50
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0226 - acc: 0.9918 - val_loss: 0.0315 - val_acc: 0.9900
# Epoch 41/50
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0153 - acc: 0.9942 - val_loss: 0.3125 - val_acc: 0.8893
# Epoch 42/50
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0130 - acc: 0.9950 - val_loss: 0.0331 - val_acc: 0.9899
# Epoch 43/50
# 8000/8000 [==============================] - 95s 12ms/sample - loss: 0.0121 - acc: 0.9954 - val_loss: 0.0957 - val_acc: 0.9712
# Epoch 44/50
# 8000/8000 [==============================] - 95s 12ms/sample - loss: 0.0115 - acc: 0.9956 - val_loss: 0.0271 - val_acc: 0.9918
# Epoch 45/50
# 8000/8000 [==============================] - 95s 12ms/sample - loss: 0.0116 - acc: 0.9956 - val_loss: 0.7844 - val_acc: 0.7792
# Epoch 46/50
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0247 - acc: 0.9910 - val_loss: 0.7887 - val_acc: 0.7575
# Epoch 47/50
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0131 - acc: 0.9950 - val_loss: 0.9677 - val_acc: 0.7741
# Epoch 48/50
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0113 - acc: 0.9957 - val_loss: 0.2890 - val_acc: 0.9151
# Epoch 49/50
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0168 - acc: 0.9939 - val_loss: 0.7470 - val_acc: 0.7885
# Epoch 50/50
# 8000/8000 [==============================] - 95s 12ms/sample - loss: 0.0142 - acc: 0.9947 - val_loss: 1.0061 - val_acc: 0.7540

# %% [markdown]
# #### Visualización de los datos de entrenamiento

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.savefig('C:/Users/GIIEE/Documents/johan/proyecto/modelos/Loss_' + simulation + '_' + str(n_classes) + '.jpg')
plt.legend()
plt.show()

if simulation == 'cells':
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    plt.plot(epochs, acc, 'y', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
    plt.title('Training and validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.savefig('C:/Users/GIIEE/Documents/johan/proyecto/modelos/acc_' + simulation + '_' + str(n_classes) + '.png')
    plt.legend()
    plt.show()

# %% [markdown]
# #### Predicción de algunos datos

# %%
# Se cargan los pesos del modelo guardado
model.load_weights('C:/Users/GIIEE/Documents/johan/proyecto/modelos/indoor_' + simulation + '_' + str(n_classes) + '.h5')  

test_img_number = random.randint(0, len(X_val))
test_img = X_val[test_img_number]
ground_truth = y_val[test_img_number]
test_img_input = np.expand_dims(test_img, 0)
inicio = time.time()
prediction = model.predict(test_img_input)
fin = time.time()
print(f'El tiempo ejecutado para el cálculo es de: {fin-inicio} segundos') 

print(test_img.shape)
print(test_img_input.shape)
print(prediction.shape)
print(ground_truth.shape)

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0])
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0])
plt.subplot(233)
plt.title('Prediction on test image')
if simulation == 'cells':
    predicted_img = np.argmax(prediction, axis=3)[0,:,:]
    plt.imshow(predicted_img)
if simulation == 'maps':
    plt.imshow(prediction[0,:,:,0])
plt.show()
# Out:
# El tiempo ejecutado para el cálculo es de: 0.05216193199157715 segundos
# (256, 256, 4)
# (1, 256, 256, 4)
# (1, 256, 256, 2)
# (256, 256, 1)
