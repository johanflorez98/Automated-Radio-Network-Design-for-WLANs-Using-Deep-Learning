# %% [markdown]
# ### Arquitectura UNet para la estimación de mapas de radio y clasificación de celdas, para escenarios de interiores

# %% [markdown]
# #### Cargue de librerías

# %%
import tensorflow as tf 
from tensorflow.keras import optimizers
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Activation, ReLU
from tensorflow.keras.layers import BatchNormalization, Conv2DTranspose, Concatenate, Dropout
from tensorflow.keras.models import Model, Sequential
import numpy as np
import os
from skimage import io
import matplotlib.pyplot as plt
from tqdm import tqdm 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import time
import random

# %% [markdown]
# ### Inicialización de algunos parámetros principales

# %%
n_classes = 3 # Cuando n_classes es igual a 1 no se puede especificar simulation = cells, ya que el sistema no realiza esta práctica, al asumirse que con
# 1 celda se cubre toda el área de funcionamiento.
simulation = 'maps'
porc_val = 0.2
epochs = 500
batch_size = 16
learning_rate = 1e-3
higth_img = 256 
width_img = 256
scenarios = 10
positions = 1000 # Se elige cuántas simulaciones se desean cargan de 1000 totales por escenario

# Algunas configuraciones para el optimizador
"""lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate = 1e-2,
    decay_steps = 5000,
    decay_rate = 0.9)"""

dir_dataset_esc = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/Escenarios'
if n_classes == 5:
    dir_dataset_pos = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/5AP/Transmisores'
    dir_masks = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/5AP/Celdas'
    dir_maps = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/5AP/Mapas'
if n_classes == 4:
    dir_dataset_pos = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/4AP/Transmisores'
    dir_masks = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/4AP/Celdas'
    dir_maps = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/4AP/Mapas'
if n_classes == 3:
    dir_dataset_pos = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/3AP/Transmisores'
    dir_masks = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/3AP/Celdas'
    dir_maps = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/3AP/Mapas'
if n_classes == 2:
    dir_dataset_pos = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/2AP/Transmisores'
    dir_masks = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/2AP/Celdas'
    dir_maps = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/2AP/Mapas'
if n_classes == 1:
    dir_dataset_pos = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/1AP/Transmisores'
    dir_maps = 'C:/Users/GIIEE/Documents/johan/proyecto/DataSet/1AP/Mapas'

# %% [markdown]
# #### Funciones para definir la arquitectura UNet

# %%
################################################################
def block_1convolution(input_b1 = None, filters = None, kernel = None, train = True):
    conv1 = Conv2D(filters, kernel, padding = 'same', kernel_initializer='he_normal', trainable = train)(input_b1)
    batch_norm1 = BatchNormalization(trainable = train)(conv1)
    act1 = ReLU(trainable = train)(batch_norm1)
    
    return act1
################################################################
def block_2convolution(input_b2 = None, filters = None, kernel = None, train = True):
    conv1 = Conv2D(filters//2, kernel, padding = 'same', kernel_initializer='he_normal', trainable = train)(input_b2)
    batch_norm1 = BatchNormalization(trainable = train)(conv1)
    act1 = ReLU(trainable = train)(batch_norm1)
    
    conv2 = Conv2D(filters, kernel, padding = 'same', kernel_initializer='he_normal', trainable = train)(act1)
    batch_norm2 = BatchNormalization(trainable = train)(conv2)
    act2 = ReLU(trainable = train)(batch_norm2)
    
    return act2
###############################################################
def encoder(input_enc = None, filters = None, kernel = None, train = True):
    enc1 = block_2convolution(input_enc, filters, kernel, train = train)
    MaxPool1 = MaxPooling2D(strides = (2,2), trainable = train)(enc1)
    return enc1, MaxPool1
###############################################################
def decoder(input_dec = None, skip = None, filters = None, kernel = None, train = True):
    Upsample = Conv2DTranspose(filters, (2, 2), strides=2, padding = 'same', trainable = train)(input_dec)
    Connect_Skip = Concatenate(trainable = train)([Upsample, skip])
    out = block_2convolution(Connect_Skip, filters, kernel, train = train)
    return out
###############################################################
def U_Net(n_classes = None, higth_img = None, width_img = None, channels_img = None, 
          simulation = ''):

    # Entrada
    input1 = Input((higth_img, width_img, channels_img))
    
    #256,256,profundidad
    skip1_1, encoder_1_1 = encoder(input1, filters = 6, kernel = 3) #128,128,profundidad
    skip2_1, encoder_2_1 = encoder(encoder_1_1, filters = 40, kernel = 3) #64,64,profundidad
    skip3_1, encoder_3_1 = encoder(encoder_2_1, filters = 50, kernel = 3) #32,32,profundidad
    skip4_1, encoder_4_1 = encoder(encoder_3_1, filters = 60, kernel = 3) #16,16,profundidad
    skip5_1, encoder_5_1 = encoder(encoder_4_1, filters = 100, kernel = 3) #8,8,profundidad
    skip6_1, encoder_6_1 = encoder(encoder_5_1, filters = 200, kernel = 3) #4,4,profundidad
    skip7_1, encoder_7_1 = encoder(encoder_6_1, filters = 300, kernel = 3) #2,2,profundidad
    skip8_1, encoder_8_1 = encoder(encoder_7_1, filters = 400, kernel = 3) #1,1,profundidad
    
    conv_block_1 = block_2convolution(encoder_8_1, filters = 600, kernel = 3) #1,1,profundidad
    
    decoder_1_1 = decoder(conv_block_1, skip8_1, filters = 400, kernel = 3) #2,2,profundidad
    decoder_2_1 = decoder(decoder_1_1, skip7_1, filters = 300, kernel = 3) #4,4,profundidad
    decoder_3_1 = decoder(decoder_2_1, skip6_1, filters = 200, kernel = 3) #8,8,profundidad
    decoder_4_1 = decoder(decoder_3_1, skip5_1, filters = 100, kernel = 3) #16,16,profundidad
    decoder_5_1 = decoder(decoder_4_1, skip4_1, filters = 60, kernel = 3) #32,32,profundidad
    decoder_6_1 = decoder(decoder_5_1, skip3_1, filters = 50, kernel = 3) #64,64,profundidad
    decoder_7_1 = decoder(decoder_6_1, skip2_1, filters = 40, kernel = 3) #128,128,profundidad       
    decoder_8_1 = decoder(decoder_7_1, skip1_1, filters = 20, kernel = 3) #256,256,profundidad
    
    conc1_1 = Concatenate()([decoder_8_1, input1])
    
    aditional_ = block_1convolution(conc1_1, filters = 20, kernel = 3) #256,256,profundidad
  
    conc2_1 = Concatenate()([aditional_, input1])
    
    if simulation == 'maps':
        out_1 = Conv2D(1, 1, padding = 'same', activation = 'relu', kernel_initializer='he_normal')(conc2_1)
    if simulation == 'cells':
        out_1 = Conv2D(n_classes, 1, padding = 'same', activation = 'softmax', kernel_initializer='he_normal')(conc2_1)
    
    model = Model(input1, out_1)
    
    return model
###############################################################

# %% [markdown]
# #### Visualización de la Arquitectura

# %%
if simulation == 'cells':
    channels_img = n_classes + 2
if simulation == 'maps':
    channels_img = n_classes + 1

model = U_Net(n_classes = n_classes, channels_img = channels_img, simulation = simulation)

model.summary()

for l in model.layers:
    print(l.name, l.trainable)

tf.keras.utils.plot_model(model, 'C:/Users/GIIEE/Documents/johan/proyecto/modelos/model.png', 
                          show_shapes=False, show_layer_names=True, 
                          rankdir='TB', expand_nested=False, dpi=110)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, None, None, 3 111         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, None, None, 3 12          conv2d_72[0][0]
# __________________________________________________________________________________________________
# re_lu_70 (ReLU)                 (None, None, None, 3 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, None, None, 6 168         re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, None, None, 6 24          conv2d_73[0][0]
# __________________________________________________________________________________________________
# re_lu_71 (ReLU)                 (None, None, None, 6 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, None, None, 6 0           re_lu_71[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, None, None, 2 1100        max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, None, None, 2 80          conv2d_74[0][0]
# __________________________________________________________________________________________________
# re_lu_72 (ReLU)                 (None, None, None, 2 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 4 7240        re_lu_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, None, None, 4 160         conv2d_75[0][0]
# __________________________________________________________________________________________________
# re_lu_73 (ReLU)                 (None, None, None, 4 0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, None, None, 4 0           re_lu_73[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, None, None, 2 9025        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, None, None, 2 100         conv2d_76[0][0]
# __________________________________________________________________________________________________
# re_lu_74 (ReLU)                 (None, None, None, 2 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, None, None, 5 11300       re_lu_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, None, None, 5 200         conv2d_77[0][0]
# __________________________________________________________________________________________________
# re_lu_75 (ReLU)                 (None, None, None, 5 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, None, None, 5 0           re_lu_75[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, None, None, 3 13530       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, None, None, 3 120         conv2d_78[0][0]
# __________________________________________________________________________________________________
# re_lu_76 (ReLU)                 (None, None, None, 3 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, None, None, 6 16260       re_lu_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, None, None, 6 240         conv2d_79[0][0]
# __________________________________________________________________________________________________
# re_lu_77 (ReLU)                 (None, None, None, 6 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, None, None, 6 0           re_lu_77[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, None, None, 5 27050       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, None, None, 5 200         conv2d_80[0][0]
# __________________________________________________________________________________________________
# re_lu_78 (ReLU)                 (None, None, None, 5 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, None, None, 1 45100       re_lu_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, None, None, 1 400         conv2d_81[0][0]
# __________________________________________________________________________________________________
# re_lu_79 (ReLU)                 (None, None, None, 1 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, None, None, 1 0           re_lu_79[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, None, None, 1 90100       max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, None, None, 1 400         conv2d_82[0][0]
# __________________________________________________________________________________________________
# re_lu_80 (ReLU)                 (None, None, None, 1 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, None, None, 2 180200      re_lu_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, None, None, 2 800         conv2d_83[0][0]
# __________________________________________________________________________________________________
# re_lu_81 (ReLU)                 (None, None, None, 2 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, None, None, 2 0           re_lu_81[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, None, None, 1 270150      max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, None, None, 1 600         conv2d_84[0][0]
# __________________________________________________________________________________________________
# re_lu_82 (ReLU)                 (None, None, None, 1 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, None, None, 3 405300      re_lu_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, None, None, 3 1200        conv2d_85[0][0]
# __________________________________________________________________________________________________
# re_lu_83 (ReLU)                 (None, None, None, 3 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, None, None, 3 0           re_lu_83[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, None, None, 2 540200      max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, None, None, 2 800         conv2d_86[0][0]
# __________________________________________________________________________________________________
# re_lu_84 (ReLU)                 (None, None, None, 2 0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, None, None, 4 720400      re_lu_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, None, None, 4 1600        conv2d_87[0][0]
# __________________________________________________________________________________________________
# re_lu_85 (ReLU)                 (None, None, None, 4 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, None, None, 4 0           re_lu_85[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, None, None, 3 1080300     max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, None, None, 3 1200        conv2d_88[0][0]
# __________________________________________________________________________________________________
# re_lu_86 (ReLU)                 (None, None, None, 3 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, None, None, 6 1620600     re_lu_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, None, None, 6 2400        conv2d_89[0][0]
# __________________________________________________________________________________________________
# re_lu_87 (ReLU)                 (None, None, None, 6 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, None, None, 4 960400      re_lu_87[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, None, None, 8 0           conv2d_transpose_16[0][0]
#                                                                  re_lu_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, None, None, 2 1440200     concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, None, None, 2 800         conv2d_90[0][0]
# __________________________________________________________________________________________________
# re_lu_88 (ReLU)                 (None, None, None, 2 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, None, None, 4 720400      re_lu_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, None, None, 4 1600        conv2d_91[0][0]
# __________________________________________________________________________________________________
# re_lu_89 (ReLU)                 (None, None, None, 4 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, None, None, 3 480300      re_lu_89[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, None, None, 6 0           conv2d_transpose_17[0][0]
#                                                                  re_lu_83[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, None, None, 1 810150      concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, None, None, 1 600         conv2d_92[0][0]
# __________________________________________________________________________________________________
# re_lu_90 (ReLU)                 (None, None, None, 1 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, None, None, 3 405300      re_lu_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, None, None, 3 1200        conv2d_93[0][0]
# __________________________________________________________________________________________________
# re_lu_91 (ReLU)                 (None, None, None, 3 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, None, None, 2 240200      re_lu_91[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, None, None, 4 0           conv2d_transpose_18[0][0]
#                                                                  re_lu_81[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, None, None, 1 360100      concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, None, None, 1 400         conv2d_94[0][0]
# __________________________________________________________________________________________________
# re_lu_92 (ReLU)                 (None, None, None, 1 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, None, None, 2 180200      re_lu_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, None, None, 2 800         conv2d_95[0][0]
# __________________________________________________________________________________________________
# re_lu_93 (ReLU)                 (None, None, None, 2 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_19 (Conv2DTran (None, None, None, 1 80100       re_lu_93[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, None, None, 2 0           conv2d_transpose_19[0][0]
#                                                                  re_lu_79[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, None, None, 5 90050       concatenate_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, None, None, 5 200         conv2d_96[0][0]
# __________________________________________________________________________________________________
# re_lu_94 (ReLU)                 (None, None, None, 5 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, None, None, 1 45100       re_lu_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, None, None, 1 400         conv2d_97[0][0]
# __________________________________________________________________________________________________
# re_lu_95 (ReLU)                 (None, None, None, 1 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, None, None, 6 24060       re_lu_95[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, None, None, 1 0           conv2d_transpose_20[0][0]
#                                                                  re_lu_77[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, None, None, 3 32430       concatenate_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, None, None, 3 120         conv2d_98[0][0]
# __________________________________________________________________________________________________
# re_lu_96 (ReLU)                 (None, None, None, 3 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, None, None, 6 16260       re_lu_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, None, None, 6 240         conv2d_99[0][0]
# __________________________________________________________________________________________________
# re_lu_97 (ReLU)                 (None, None, None, 6 0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, None, None, 5 12050       re_lu_97[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, None, None, 1 0           conv2d_transpose_21[0][0]
#                                                                  re_lu_75[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, None, None, 2 22525       concatenate_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, None, None, 2 100         conv2d_100[0][0]
# __________________________________________________________________________________________________
# re_lu_98 (ReLU)                 (None, None, None, 2 0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, None, None, 5 11300       re_lu_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, None, None, 5 200         conv2d_101[0][0]
# __________________________________________________________________________________________________
# re_lu_99 (ReLU)                 (None, None, None, 5 0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, None, None, 4 8040        re_lu_99[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, None, None, 8 0           conv2d_transpose_22[0][0]
#                                                                  re_lu_73[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, None, None, 2 14420       concatenate_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, None, None, 2 80          conv2d_102[0][0]
# __________________________________________________________________________________________________
# re_lu_100 (ReLU)                (None, None, None, 2 0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, None, None, 4 7240        re_lu_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, None, None, 4 160         conv2d_103[0][0]
# __________________________________________________________________________________________________
# re_lu_101 (ReLU)                (None, None, None, 4 0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, None, None, 2 3220        re_lu_101[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, None, None, 2 0           conv2d_transpose_23[0][0]
#                                                                  re_lu_71[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, None, None, 1 2350        concatenate_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, None, None, 1 40          conv2d_104[0][0]
# __________________________________________________________________________________________________
# re_lu_102 (ReLU)                (None, None, None, 1 0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, None, None, 2 1820        re_lu_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, None, None, 2 80          conv2d_105[0][0]
# __________________________________________________________________________________________________
# re_lu_103 (ReLU)                (None, None, None, 2 0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, None, None, 2 0           re_lu_103[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, None, None, 2 4340        concatenate_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, None, None, 2 80          conv2d_106[0][0]
# __________________________________________________________________________________________________
# re_lu_104 (ReLU)                (None, None, None, 2 0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, None, None, 2 0           re_lu_104[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, None, None, 1 25          concatenate_29[0][0]
# ==================================================================================================
# Total params: 11,028,350
# Trainable params: 11,019,532
# Non-trainable params: 8,818
# __________________________________________________________________________________________________
# input_3 True
# conv2d_72 True
# batch_normalization_70 True
# re_lu_70 True
# conv2d_73 True
# batch_normalization_71 True
# re_lu_71 True
# max_pooling2d_16 True
# conv2d_74 True
# batch_normalization_72 True
# re_lu_72 True
# conv2d_75 True
# batch_normalization_73 True
# re_lu_73 True
# max_pooling2d_17 True
# conv2d_76 True
# batch_normalization_74 True
# re_lu_74 True
# conv2d_77 True
# batch_normalization_75 True
# re_lu_75 True
# max_pooling2d_18 True
# conv2d_78 True
# batch_normalization_76 True
# re_lu_76 True
# conv2d_79 True
# batch_normalization_77 True
# re_lu_77 True
# max_pooling2d_19 True
# conv2d_80 True
# batch_normalization_78 True
# re_lu_78 True
# conv2d_81 True
# batch_normalization_79 True
# re_lu_79 True
# max_pooling2d_20 True
# conv2d_82 True
# batch_normalization_80 True
# re_lu_80 True
# conv2d_83 True
# batch_normalization_81 True
# re_lu_81 True
# max_pooling2d_21 True
# conv2d_84 True
# batch_normalization_82 True
# re_lu_82 True
# conv2d_85 True
# batch_normalization_83 True
# re_lu_83 True
# max_pooling2d_22 True
# conv2d_86 True
# batch_normalization_84 True
# re_lu_84 True
# conv2d_87 True
# batch_normalization_85 True
# re_lu_85 True
# max_pooling2d_23 True
# conv2d_88 True
# batch_normalization_86 True
# re_lu_86 True
# conv2d_89 True
# batch_normalization_87 True
# re_lu_87 True
# conv2d_transpose_16 True
# concatenate_20 True
# conv2d_90 True
# batch_normalization_88 True
# re_lu_88 True
# conv2d_91 True
# batch_normalization_89 True
# re_lu_89 True
# conv2d_transpose_17 True
# concatenate_21 True
# conv2d_92 True
# batch_normalization_90 True
# re_lu_90 True
# conv2d_93 True
# batch_normalization_91 True
# re_lu_91 True
# conv2d_transpose_18 True
# concatenate_22 True
# conv2d_94 True
# batch_normalization_92 True
# re_lu_92 True
# conv2d_95 True
# batch_normalization_93 True
# re_lu_93 True
# conv2d_transpose_19 True
# concatenate_23 True
# conv2d_96 True
# batch_normalization_94 True
# re_lu_94 True
# conv2d_97 True
# batch_normalization_95 True
# re_lu_95 True
# conv2d_transpose_20 True
# concatenate_24 True
# conv2d_98 True
# batch_normalization_96 True
# re_lu_96 True
# conv2d_99 True
# batch_normalization_97 True
# re_lu_97 True
# conv2d_transpose_21 True
# concatenate_25 True
# conv2d_100 True
# batch_normalization_98 True
# re_lu_98 True
# conv2d_101 True
# batch_normalization_99 True
# re_lu_99 True
# conv2d_transpose_22 True
# concatenate_26 True
# conv2d_102 True
# batch_normalization_100 True
# re_lu_100 True
# conv2d_103 True
# batch_normalization_101 True
# re_lu_101 True
# conv2d_transpose_23 True
# concatenate_27 True
# conv2d_104 True
# batch_normalization_102 True
# re_lu_102 True
# conv2d_105 True
# batch_normalization_103 True
# re_lu_103 True
# concatenate_28 True
# conv2d_106 True
# batch_normalization_104 True
# re_lu_104 True
# concatenate_29 True
# conv2d_107 True
# Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.

# %% [markdown]
# #### Cargue de los datos

# %%
def data(simulation = '', n_classes = None, dir_dataset_pos = '', dir_masks = '', dir_maps = '',
        dir_dataset_esc = '', scenarios = None, positions = None):

    maps_inds = np.arange(1, (scenarios * positions) + 1, 1, dtype = np.int16) 
    np.random.seed(42) # Semilla para tener siempre los numeros aleatorios
    np.random.shuffle(maps_inds)

    train_images = []

    train_masks = [] 

    for idx in tqdm(maps_inds):
        idxr = np.floor((idx - 1)/positions).astype(int)
        idxc = idx - (idxr * positions)
        dataset_map_ind = idxr + 1

        name_buildings = str(dataset_map_ind) + ".png"
        name_maps = str(dataset_map_ind) + "_" + str(idxc) + ".png"
        name_tx1 = str(dataset_map_ind) + "_" + str(idxc) + ".png"
        
        if n_classes > 1:
            name_tx1 = str(dataset_map_ind) + "_" + str(idxc) + "_" + '1' + ".png"
            name_tx2 = str(dataset_map_ind) + "_" + str(idxc) + "_" + '2' + ".png"
            
        if n_classes > 2:
            name_tx3 = str(dataset_map_ind) + "_" + str(idxc) + "_" + '3' + ".png"
            
        if n_classes > 3:
            name_tx4 = str(dataset_map_ind) + "_" + str(idxc) + "_" + '4' + ".png"
            
        if n_classes > 4:
            name_tx5 = str(dataset_map_ind) + "_" + str(idxc) + "_" + '5' + ".png"

        img_name_buildings = os.path.join(dir_dataset_esc, name_buildings)
        image_buildings = np.asarray(io.imread(img_name_buildings))/255

        img_name_Tx1 = os.path.join(dir_dataset_pos, name_tx1)
        image_Tx1 = np.asarray(io.imread(img_name_Tx1))/255

        if n_classes > 1:
            img_name_Tx2 = os.path.join(dir_dataset_pos, name_tx2)
            image_Tx2 = np.asarray(io.imread(img_name_Tx2))/255

        if n_classes > 2:
            img_name_Tx3 = os.path.join(dir_dataset_pos, name_tx3)
            image_Tx3 = np.asarray(io.imread(img_name_Tx3))/255
            
        if n_classes > 3:
            img_name_Tx4 = os.path.join(dir_dataset_pos, name_tx4)
            image_Tx4 = np.asarray(io.imread(img_name_Tx4))/255
            
        if n_classes > 4:
            img_name_Tx5 = os.path.join(dir_dataset_pos, name_tx5)
            image_Tx5 = np.asarray(io.imread(img_name_Tx5))/255

        if n_classes == 1:
            img = np.stack([image_buildings, image_Tx1], axis = 2)  
            train_images.append(img)    
            
        if n_classes == 2 and simulation == 'maps':
            img = np.stack([image_buildings, image_Tx1, image_Tx2], axis = 2)  
            train_images.append(img)
            
        if n_classes == 2 and simulation == 'cells':
            maps1 = os.path.join(dir_maps, name_maps)
            maps1 = np.asarray(io.imread(maps1))/255
            img = np.stack([image_buildings, image_Tx1, image_Tx2, maps1], axis = 2)  
            train_images.append(img)
            
        if n_classes == 3 and simulation == 'maps':
            img = np.stack([image_buildings, image_Tx1, image_Tx2, image_Tx3], axis = 2)  
            train_images.append(img) 
            
        if n_classes == 3 and simulation == 'cells':
            maps1 = os.path.join(dir_maps, name_maps)
            maps1 = np.asarray(io.imread(maps1))/255
            img = np.stack([image_buildings, image_Tx1, image_Tx2, image_Tx3, maps1], axis = 2)  
            train_images.append(img)
            
        if n_classes == 4 and simulation == 'maps':
            img = np.stack([image_buildings, image_Tx1, image_Tx2, image_Tx3, image_Tx4], axis = 2)  
            train_images.append(img) 
            
        if n_classes == 4 and simulation == 'cells':
            maps1 = os.path.join(dir_maps, name_maps)
            maps1 = np.asarray(io.imread(maps1))/255
            img = np.stack([image_buildings, image_Tx1, image_Tx2, image_Tx3, image_Tx4, maps1], axis = 2)  
            train_images.append(img)
            
        if n_classes == 5 and simulation == 'maps':
            img = np.stack([image_buildings, image_Tx1, image_Tx2, image_Tx3, image_Tx4, image_Tx5], axis = 2)  
            train_images.append(img) 
            
        if n_classes == 5 and simulation == 'cells':
            maps1 = os.path.join(dir_maps, name_maps)
            maps1 = np.asarray(io.imread(maps1))/255
            img = np.stack([image_buildings, image_Tx1, image_Tx2, image_Tx3, image_Tx4, image_Tx5, maps1], axis = 2)  
            train_images.append(img)

        if simulation == 'maps':    
            img_name_out = os.path.join(dir_maps, name_maps)  
            image_out = np.asarray(io.imread(img_name_out))/255
            train_masks.append(image_out)
        
        if simulation == 'cells' and n_classes != 1:    
            img_name_out = os.path.join(dir_masks, name_maps)  
            image_out = np.asarray(io.imread(img_name_out))
            train_masks.append(image_out)

    train_images = np.array(train_images)
    train_masks = np.array(train_masks)

    if simulation == 'maps': 
        train_masks_input = np.expand_dims(train_masks, axis=3)
        
    if simulation == 'cells': 
        labelencoder = LabelEncoder()
        n, h, w = train_masks.shape
        train_masks_reshaped = train_masks.reshape(-1,1)
        train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
        train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)
        train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)
    
    return train_images, train_masks_input
    
if n_classes == 1:   
    train_images, train_masks_input = data(simulation = simulation, n_classes = n_classes, 
                                        dir_dataset_pos = dir_dataset_pos, 
                                        dir_maps = dir_maps, dir_dataset_esc = dir_dataset_esc, 
                                        scenarios = scenarios, positions = positions)
else:
    train_images, train_masks_input = data(simulation = simulation, n_classes = n_classes, 
                                       dir_dataset_pos = dir_dataset_pos, dir_masks = dir_masks, 
                                       dir_maps = dir_maps, dir_dataset_esc = dir_dataset_esc, 
                                       scenarios = scenarios, positions = positions)
# Out:
# 100%|██████████| 10000/10000 [01:02<00:00, 160.13it/s]

# %%
print(train_images.shape)
print(train_masks_input.shape)
# Out:
# (10000, 256, 256, 4)
# (10000, 256, 256, 1)

# %% [markdown]
# #### Separación de los datos en entrenamiento y validación

# %%
X_train, X_val, y_train, y_val = train_test_split(train_images, train_masks_input, 
                                                  test_size = porc_val, random_state = 0)

# %% [markdown]
# #### Visualización de algunos datos

# %%
grapics = 20
imgs = X_train[:grapics,...]
masks = y_train[:grapics,...]
def plot_data(imgs, masks):
    plt.figure(figsize=(20,10))
    for i in range(grapics):
        plt.subplot(4, 5, i+1)
        img=imgs[i,...]
        mask = masks[i, ...]
        plt.imshow(img[:,:,0])
        plt.imshow(mask[:,:,0], alpha=0.5)
        #print(np.unique(mask[:,:,0]))
        
        plt.axis('Off')
    plt.tight_layout()
    plt.show()

plot_data(imgs, masks)

# %% [markdown]
# #### Adecuación de la salida de las celdas en one-hot (si se requiere) y entrenamiento del modelo

# %%
optimizer = optimizers.Adam(learning_rate = learning_rate)

if simulation == 'cells':
    model.compile(optimizer = optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
if simulation == 'maps':
    model.compile(optimizer = optimizer, loss='mean_squared_error')

def training(model, simulation = '', n_classes = None, y_train = [], y_val = [], 
             epochs = None, batch_size = None):
    
    if simulation == 'cells':
        print('Valores únicos de clases: ', np.unique(y_train)) 
        
        y_train_cat = to_categorical(y_train, num_classes = n_classes)

        y_val_cat = to_categorical(y_val, num_classes = n_classes)
        
        callbacks = [keras.callbacks.ModelCheckpoint('C:/Users/GIIEE/Documents/johan/proyecto/modelos/indoor_' + 
                                                     simulation + '_' + str(n_classes) + '.h5', 
                                                     save_best_only = True)]

        history = model.fit(X_train, y_train_cat, 
                            batch_size = batch_size, 
                            verbose = 1, 
                            epochs = epochs, 
                            validation_data = (X_val, y_val_cat), 
                            callbacks = callbacks,
                            shuffle = False)
        
    if simulation == 'maps':
        callbacks = [keras.callbacks.ModelCheckpoint('C:/Users/GIIEE/Documents/johan/proyecto/modelos/indoor_' + 
                                                     simulation + '_' + str(n_classes) + '.h5', 
                                                     save_best_only = True)]

        history = model.fit(X_train, y_train, 
                            batch_size = batch_size, 
                            verbose = 1, 
                            epochs = epochs, 
                            validation_data = (X_val, y_val), 
                            callbacks = callbacks,
                            shuffle = False)
    
    return history
        
    ###############################################################################    
    
# Cambiar de acuerdo al problema *******************************************************
history = training(model = model, simulation = simulation, n_classes = n_classes, 
                   y_train = y_train, y_val = y_val, epochs = epochs, batch_size = batch_size
                   )
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/500
# 8000/8000 [==============================] - 119s 15ms/sample - loss: 0.0267 - val_loss: 0.0170
# Epoch 2/500
# 8000/8000 [==============================] - 90s 11ms/sample - loss: 0.0063 - val_loss: 0.0058
# Epoch 3/500
# 8000/8000 [==============================] - 92s 11ms/sample - loss: 0.0021 - val_loss: 0.0036
# Epoch 4/500
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 0.0022 - val_loss: 0.0026
# Epoch 5/500
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 0.0016 - val_loss: 0.0022
# Epoch 6/500
# 8000/8000 [==============================] - 92s 12ms/sample - loss: 0.0019 - val_loss: 0.0022
# Epoch 7/500
# 8000/8000 [==============================] - 92s 12ms/sample - loss:
500
# 8000/8000 [==============================] - 92s 11ms/sample - loss: 8.4657e-05 - val_loss: 4.7461e-04
# Epoch 487/500
# 8000/8000 [==============================] - 92s 11ms/sample - loss: 8.8250e-05 - val_loss: 4.6966e-04
# Epoch 488/500
# 8000/8000 [==============================] - 98s 12ms/sample - loss: 8.4777e-05 - val_loss: 4.9147e-04
# Epoch 489/500
# 8000/8000 [==============================] - 94s 12ms/sample - loss: 7.9475e-05 - val_loss: 5.1504e-04
# Epoch 490/500
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 7.9091e-05 - val_loss: 4.8445e-04
# Epoch 491/500
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 8.0271e-05 - val_loss: 4.5981e-04
# Epoch 492/500
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 8.3763e-05 - val_loss: 4.6914e-04
# Epoch 493/500
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 8.3659e-05 - val_loss: 4.8296e-04
# Epoch 494/500
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 8.3958e-05 - val_loss: 4.7288e-04
# Epoch 495/500
# 8000/8000 [==============================] - 92s 12ms/sample - loss: 8.1139e-05 - val_loss: 4.5101e-04
# Epoch 496/500
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 8.3555e-05 - val_loss: 4.4596e-04
# Epoch 497/500
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 8.8735e-05 - val_loss: 4.5196e-04
# Epoch 498/500
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 9.5047e-05 - val_loss: 4.6047e-04
# Epoch 499/500
# 8000/8000 [==============================] - 93s 12ms/sample - loss: 9.5437e-05 - val_loss: 4.5627e-04
# Epoch 500/500
# 8000/8000 [==============================] - 92s 12ms/sample - loss: 8.9688e-05 - val_loss: 4.5575e-04

# %% [markdown]
# #### Visualización de los datos de entrenamiento

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.savefig('C:/Users/GIIEE/Documents/johan/proyecto/modelos/Loss_' + simulation + '_' + str(n_classes) + '.jpg')
plt.legend()
plt.show()

if simulation == 'cells':
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    plt.plot(epochs, acc, 'y', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
    plt.title('Training and validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.savefig('C:/Users/GIIEE/Documents/johan/proyecto/modelos/acc_' + simulation + '_' + str(n_classes) + '.png')
    plt.legend()
    plt.show()

# %% [markdown]
# #### Predicción de algunos datos

# %%
# Se cargan los pesos del modelo guardado
model.load_weights('C:/Users/GIIEE/Documents/johan/proyecto/modelos/indoor_' + simulation + '_' + str(n_classes) + '.h5')  

test_img_number = random.randint(0, len(X_val))
test_img = X_val[test_img_number]
ground_truth = y_val[test_img_number]
test_img_input = np.expand_dims(test_img, 0)
inicio = time.time()
prediction = model.predict(test_img_input)
fin = time.time()
print(f'El tiempo ejecutado para el cálculo es de: {fin-inicio} segundos') 

print(test_img.shape)
print(test_img_input.shape)
print(prediction.shape)
print(ground_truth.shape)

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,0])
plt.subplot(232)
if simulation == 'cells':
    plt.title('Testing Label')
if simulation == 'maps':
    plt.title('Testing Level')
plt.imshow(ground_truth[:,:,0])
plt.subplot(233)
plt.title('Prediction on test image')
if simulation == 'cells':
    predicted_img = np.argmax(prediction, axis=3)[0,:,:]
    plt.imshow(predicted_img)
    plt.savefig('C:/Users/GIIEE/Documents/johan/proyecto/modelos/eval_' + simulation + '_' + str(n_classes) + '.png')
if simulation == 'maps':
    plt.imshow(prediction[0,:,:,0])
    plt.savefig('C:/Users/GIIEE/Documents/johan/proyecto/modelos/eval_' + simulation + '_' + str(n_classes) + '.png')
plt.show()
# Out:
# El tiempo ejecutado para el cálculo es de: 0.60589599609375 segundos
# (256, 256, 4)
# (1, 256, 256, 4)
# (1, 256, 256, 1)
# (256, 256, 1)
